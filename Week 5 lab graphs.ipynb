# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inside_data = pd.read_csv("Combo_Data_Inside.csv")
outside_data = pd.read_csv("Combo_Data_Outside.csv")
x0 = inside_data['PM1.0']
x1 = inside_data['PM2.5']
x2 = inside_data['PM10']
x3 = inside_data['Temp']
x4 = inside_data['Gas']
x5 = inside_data['Humidity']
x6 = inside_data['Pressure']
x7 = inside_data['Altitude']

y0 = outside_data['PM1.0']
y1 = outside_data['PM2.5']
y2 = outside_data['PM10']
y3 = outside_data['Temp']
y4 = outside_data['Gas']
y5 = outside_data['Humidity']
y6 = outside_data['Pressure']
y7 = outside_data['Altitude']


plt.plot(x0)#, label = "time vs PM1.0")
#plt.ylabel('time')
#plt.xlabel('PM 1.0')
#plt.legend()
plt.show()


plt.plot(x1)
plt.show()

plt.plot(x2)
plt.show()

plt.plot(x3)
plt.show()

plt.plot(x4)
plt.show()

plt.plot(x5)
plt.show()

plt.plot(x6)
plt.show()

plt.plot(x7)
plt.show()


plt.plot(x0,y0, label = "PM1.0" )
#plt.ylabel('time')
#plt.xlabel('PM 1.0')
plt.legend()
plt.show()


#plt.plot(x1)
#plt.show()

plt.plot(x2, label = "inside PM10")
plt.plot(y2, label = "outside PM10")
plt.legend()
plt.show()


#plt.plot(x3)
#plt.show()

plt.plot(x4, label = "inside Gas")
plt.plot(y4, label = "outside Gas")
plt.legend()
plt.show()


#plt.plot(x5)
#plt.show()

plt.plot(x6, label = "inside pressure")
plt.plot(y6, label = "outside pressure")
plt.legend()
plt.show()


#plt.plot(x7)
#plt.show()

# %%
plt.hist(x2, label = "inside PM10", alpha = 0.5)
plt.hist(y2, label = "outside PM10", alpha = 0.5)
plt.legend()
plt.show()

plt.hist(x4, label = "inside Gas", alpha = 0.5)
plt.hist(y4, label = "outside Gas", alpha = 0.5)
plt.legend()
plt.show()


plt.hist(x3, label = "inside temp", alpha = 0.5)
plt.hist(y3, label = "outside temp",alpha = 0.5)
plt.legend()
plt.show()

# %% [raw]
# The PM10 inside varies much less inside than it does outside.
# The inside and outside gas both increase over time
# The inside temperature stays the same while the outside temperature changes.

# %%
std_mean_pm10_in = np.std(x2)/ np.sqrt(300)
print(std_mean_pm10_in)

std_mean_pm10_out = np.std(y2)/ np.sqrt(300)
print(std_mean_pm10_out)

diff = np.abs(std_mean_pm10_in - std_mean_pm10_out)
print(diff)

ans = np.abs(diff/(np.std(x2)/np.sqrt(300)))
print(ans)
# Out:
# 0.03981539650846858
# 0.12727389312323487
# 0.08745849661476629
# 2.1965999157176346
